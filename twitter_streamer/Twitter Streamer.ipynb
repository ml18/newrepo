# %% [markdown]
# Use `pip` to install `twitter`.

# %%
# !pip install twitter --quiet  #tweepi

# %% [markdown]
# Import `TwitterStream` and `OAuth` from `twitter`.

# %%
from twitter import TwitterStream, OAuth

# %% [markdown]
# ### `oauth`

# %% [markdown]
# Create a new object called `oauth` using `OAuth`.
#
#     OAuth(token, token_secret, consumer_key, consumer_secret)

# %%
token ="1020013622150348801-vHatyMqloUvbv42Y5RXNxtHsqlLU0Y"
token_secret="JY3N99jmjM74zAjOE25uLCwicS9ZcRtmE8sOTwYwxkSeu"
consumer_key="bgesG8uyOhFwy5xKDMWGL9Hpl"
consumer_secret="y4zfw8GW8t66pbTmNhAK6U18wuULqQNxQBpZ6FuYnP97wf1Rnd"

# %%
oauth=OAuth(token, token_secret, consumer_key, consumer_secret)

# %% [markdown]
# Create a new object called `twitter_stream` using `TwitterStream`.
#
# Use the argument `auth=oauth` referencing the `oauth` object you just made.

# %% [markdown]
# ### `twitter_stream`

# %%
twitter_stream = TwitterStream(auth=oauth)

# %% [markdown]
# ### `bounding_box`

# %% [markdown]
# Create a string called `bounding_box`. The string should contain the geo-coordinates of a bounding box separated by commas. These values are for Santa Monica:
#
#     -118.5137323688,34.0001996344,-118.4702449172,34.0331651696
#
# You can make your own here: https://boundingbox.klokantech.com. Be sure to specify CSV RAW to get the values in this format.
#
# ![](https://www.evernote.com/l/AAH3H9KGE6hD9JpPJPFncw09exRyoYSid5IB/image.png)

# %%
bounding_box='-118.5137323688,34.0001996344,-118.4702449172,34.0331651696'

# %% [markdown]
# ### `tweet_iterator`
#
# Create an object called `tweet_iterator`.
#
# 1. Use `twitter_stream`.
# 1. Apply `.statuses` to grab statuses.
# 1. Apply a `.filter()` with the argument `locations=bounding_box`.

# %%
tweet_iterator = (twitter_stream.
                  statuses.
                  filter(locations=bounding_box))

# %% [markdown]
# Get the next value from the `tweet_iterator` and store it as the variable `this_tweet`.

# %%
this_tweet = next(tweet_iterator)

# %%
this_tweet
# Out:
# {'created_at': 'Fri Jul 20 03:13:25 +0000 2018',
#  'id': 1020144622159290368,
#  'id_str': '1020144622159290368',
#  'text': '@believinAmerica @dtrusmith @jetrotter @LaylaAlisha11 And whoopi did it on the air!!!',
#  'display_text_range': [54, 85],
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'in_reply_to_status_id': 1020120498414522368,
#  'in_reply_to_status_id_str': '1020120498414522368',
#  'in_reply_to_user_id': 554739796,
#  'in_reply_to_user_id_str': '554739796',
#  'in_reply_to_screen_name': 'believinAmerica',
#  'user': {'id': 2859827501,
#   'id_str': '2859827501',
#   'name': '(((Joy Spragens)))',
#   'screen_name': 'JSpragens',
#   'location': None,
#   'url': None,
#   'description': 'Conserv Constitutionlst, own opins, sm govt big ppl,free enterprse,rt 2work,relig freedom w/out persecutn,common sense&kindnss, honor 2b followd by Marco Rubio!',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 3583,
#   'friends_count': 3886,
#   'listed_count': 80,
#   'favourites_count': 29254,
#   'statuses_count': 46552,
#   'created_at': 'Tue Nov 04 02:39:52 +0000 2014',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/593778601004269571/uwNKfRhR_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/593778601004269571/uwNKfRhR_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2859827501/1458158254',
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None},
#  'geo': None,
#  'coordinates': None,
#  'place': {'id': 'fbd6d2f5a4e4a15e',
#   'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#   'place_type': 'admin',
#   'name': 'California',
#   'full_name': 'California, USA',
#   'country_code': 'US',
#   'country': 'United States',
#   'bounding_box': {'type': 'Polygon',
#    'coordinates': [[[-124.482003, 32.528832],
#      [-124.482003, 42.009519],
#      [-114.131212, 42.009519],
#      [-114.131212, 32.528832]]]},
#   'attributes': {}},
#  'contributors': None,
#  'is_quote_status': False,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'entities': {'hashtags': [],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'believinAmerica',
#     'name': 'Lynn',
#     'id': 554739796,
#     'id_str': '554739796',
#     'indices': [0, 16]},
#    {'screen_name': 'dtrusmith',
#     'name': 'Deb',
#     'id': 482420761,
#     'id_str': '482420761',
#     'indices': [17, 27]},
#    {'screen_name': 'jetrotter',
#     'name': '#WalkAway #RedWave2018 🇺🇸',
#     'id': 94132483,
#     'id_str': '94132483',
#     'indices': [28, 38]},
#    {'screen_name': 'LaylaAlisha11',
#     'name': 'Layla {⭐}',
#     'id': 875017115979403264,
#     'id_str': '875017115979403264',
#     'indices': [39, 53]}],
#   'symbols': []},
#  'favorited': False,
#  'retweeted': False,
#  'filter_level': 'low',
#  'lang': 'en',
#  'timestamp_ms': '1532056405950'}

# %% [markdown]
# What is the type of `this_tweet`?

# %%
type(this_tweet)
# Out:
# twitter.api.TwitterDictResponse

# %% [markdown]
# Display the keys of `this_tweet`.

# %%
for item in this_tweet.items():
    print (item[0])
# Out:
# created_at
# id
# id_str
# text
# display_text_range
# source
# truncated
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# quote_count
# reply_count
# retweet_count
# favorite_count
# entities
# favorited
# retweeted
# filter_level
# lang
# timestamp_ms

# %%
this_tweet.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'display_text_range', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'])

# %% [markdown]
# Display the `text` and `user` of `this_tweet`.

# %%
text=this_tweet.get('text')
text
# Out:
# '@believinAmerica @dtrusmith @jetrotter @LaylaAlisha11 And whoopi did it on the air!!!'

# %%
type(text)
# Out:
# str

# %%
user=this_tweet.get('user')
user
# Out:
# {'id': 2859827501,
#  'id_str': '2859827501',
#  'name': '(((Joy Spragens)))',
#  'screen_name': 'JSpragens',
#  'location': None,
#  'url': None,
#  'description': 'Conserv Constitutionlst, own opins, sm govt big ppl,free enterprse,rt 2work,relig freedom w/out persecutn,common sense&kindnss, honor 2b followd by Marco Rubio!',
#  'translator_type': 'none',
#  'protected': False,
#  'verified': False,
#  'followers_count': 3583,
#  'friends_count': 3886,
#  'listed_count': 80,
#  'favourites_count': 29254,
#  'statuses_count': 46552,
#  'created_at': 'Tue Nov 04 02:39:52 +0000 2014',
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'lang': 'en',
#  'contributors_enabled': False,
#  'is_translator': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/593778601004269571/uwNKfRhR_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/593778601004269571/uwNKfRhR_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2859827501/1458158254',
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': None,
#  'follow_request_sent': None,
#  'notifications': None}

# %%
type(user)
# Out:
# dict

# %% [markdown]
# ## Collect Tweets
#
# Create an empty list called `tweets`.
#
# Use a `for`-loop to collect ten tweets and add them to this list.

# %%
tweets=[]
for i in range(10):
    this_tweet = next(tweet_iterator)
    tweets.append(this_tweet)

# %%
tweets
# Out:
# [{'created_at': 'Fri Jul 20 03:13:27 +0000 2018',
#   'id': 1020144629994274816,
#   'id_str': '1020144629994274816',
#   'text': '#statute @ Venice Boardwalk, CA https://t.co/au0dhTumh0',
#   'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 30316687,
#    'id_str': '30316687',
#    'name': 'Laura Ann Tull',
#    'screen_name': 'LauraAnnTull',
#    'location': 'Los Angeles, CA- HOME',
#    'url': 'http://m.imdb.com/name/nm1913224/bio',
#    'description': '#AtheistBuddhist #Vegan #metoo #SagAftra #Actress⭐https://t.co/77oK1KiWPX https://t.co/3xYxiCrBB1  #resignedCaliLawyer207690 #ptsd  #Autoimmune @ArtisticHOPE (A⚓™) #Dem 🎭',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 1786,
#    'friends_count': 2094,
#    'listed_count': 120,
#    'favourites_count': 1335,
#    'statuses_count': 48470,
#    'created_at': 'Fri Apr 10 21:23:59 +0000 2009',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '7A9173',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_tile': True,
#    'profile_link_color': '9869A5',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F0B8F5',
#    'profile_text_color': '331575',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/678298072405827584/4cJB3KF5_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/678298072405827584/4cJB3KF5_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/30316687/1529464640',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': {'type': 'Point', 'coordinates': [33.98793086, -118.47436432]},
#   'coordinates': {'type': 'Point',
#    'coordinates': [-118.47436432, 33.98793086]},
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'statute', 'indices': [0, 8]}],
#    'urls': [{'url': 'https://t.co/au0dhTumh0',
#      'expanded_url': 'https://www.instagram.com/p/BlcBz_4AMeX/?utm_source=ig_twitter_share&igshid=z2y3rd9e2o5n',
#      'display_url': 'instagram.com/p/BlcBz_4AMeX/…',
#      'indices': [32, 55]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056407818'},
#  {'created_at': 'Fri Jul 20 03:13:30 +0000 2018',
#   'id': 1020144643285979136,
#   'id_str': '1020144643285979136',
#   'text': '@sabbysfirstlove Yess girl recruit new CARPENTERS',
#   'display_text_range': [17, 49],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1020144466240319488,
#   'in_reply_to_status_id_str': '1020144466240319488',
#   'in_reply_to_user_id': 2864995420,
#   'in_reply_to_user_id_str': '2864995420',
#   'in_reply_to_screen_name': 'sabbysfirstlove',
#   'user': {'id': 773726292353187840,
#    'id_str': '773726292353187840',
#    'name': 'Singular//FrancineYanoria',
#    'screen_name': 'Francinealora2',
#    'location': 'Los Angeles, CA',
#    'url': 'https://www.youtube.com/channel/UCqXpYIT5aEXgDHFWBmEOH1Q',
#    'description': '"Tell me how we\'re not alike but we work so well and we don\'t even know why"',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 99,
#    'friends_count': 181,
#    'listed_count': 0,
#    'favourites_count': 994,
#    'statuses_count': 461,
#    'created_at': 'Thu Sep 08 03:34:58 +0000 2016',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1013862377245196288/BNScJtB0_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1013862377245196288/BNScJtB0_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/773726292353187840/1500660676',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'sabbysfirstlove',
#      'name': 'meg',
#      'id': 2864995420,
#      'id_str': '2864995420',
#      'indices': [0, 16]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056410987'},
#  {'created_at': 'Fri Jul 20 03:13:32 +0000 2018',
#   'id': 1020144650571546624,
#   'id_str': '1020144650571546624',
#   'text': '@JKell510 @feedcoop @brittydakitty Ya Bethany GTFOOHWTMFBS',
#   'display_text_range': [35, 58],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1020141794346930178,
#   'in_reply_to_status_id_str': '1020141794346930178',
#   'in_reply_to_user_id': 338211848,
#   'in_reply_to_user_id_str': '338211848',
#   'in_reply_to_screen_name': 'JKell510',
#   'user': {'id': 765683975138357248,
#    'id_str': '765683975138357248',
#    'name': '24_male_santamonica',
#    'screen_name': 'pquint510',
#    'location': 'Los Angeles, CA',
#    'url': None,
#    'description': 'patrick',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 85,
#    'friends_count': 96,
#    'listed_count': 0,
#    'favourites_count': 8462,
#    'statuses_count': 1583,
#    'created_at': 'Tue Aug 16 22:57:40 +0000 2016',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1014699962490183680/U5_DJaMs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1014699962490183680/U5_DJaMs_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/765683975138357248/1530649612',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '59612bd882018c51',
#    'url': 'https://api.twitter.com/1.1/geo/id/59612bd882018c51.json',
#    'place_type': 'city',
#    'name': 'Santa Monica',
#    'full_name': 'Santa Monica, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.517358, 33.995177],
#       [-118.517358, 34.050199],
#       [-118.443482, 34.050199],
#       [-118.443482, 33.995177]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'JKell510',
#      'name': 'just J Kell :/',
#      'id': 338211848,
#      'id_str': '338211848',
#      'indices': [0, 9]},
#     {'screen_name': 'feedcoop',
#      'name': '24_male_bayarea',
#      'id': 702284058932293636,
#      'id_str': '702284058932293636',
#      'indices': [10, 19]},
#     {'screen_name': 'brittydakitty',
#      'name': 'britty',
#      'id': 216606171,
#      'id_str': '216606171',
#      'indices': [20, 34]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056412724'},
#  {'created_at': 'Fri Jul 20 03:13:33 +0000 2018',
#   'id': 1020144652098330625,
#   'id_str': '1020144652098330625',
#   'text': '@Lexivnne I recognized that I was wrong and it might happen again.',
#   'display_text_range': [10, 66],
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1020144433520467968,
#   'in_reply_to_status_id_str': '1020144433520467968',
#   'in_reply_to_user_id': 170200751,
#   'in_reply_to_user_id_str': '170200751',
#   'in_reply_to_screen_name': 'Lexivnne',
#   'user': {'id': 3279122815,
#    'id_str': '3279122815',
#    'name': 'Horus',
#    'screen_name': 'FreeeLucifer',
#    'location': 'Los Angeles, CA',
#    'url': None,
#    'description': 'Comics, Sports, Gaming, Star Wars, a little anime',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 442,
#    'friends_count': 516,
#    'listed_count': 43,
#    'favourites_count': 5938,
#    'statuses_count': 33658,
#    'created_at': 'Tue Jul 14 02:06:10 +0000 2015',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1013205433480179712/VOf5QJ4o_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1013205433480179712/VOf5QJ4o_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3279122815/1531823440',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'Lexivnne',
#      'name': 'alexis',
#      'id': 170200751,
#      'id_str': '170200751',
#      'indices': [0, 9]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056413088'},
#  {'created_at': 'Fri Jul 20 03:13:33 +0000 2018',
#   'id': 1020144655868891136,
#   'id_str': '1020144655868891136',
#   'text': 'my truck stay clean from inside , im so OCD with my truck it’s insane. 😭',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 807086677315334144,
#    'id_str': '807086677315334144',
#    'name': '〰️',
#    'screen_name': 'sabrinnao_',
#    'location': 'Los Angeles, CA',
#    'url': None,
#    'description': None,
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 97,
#    'friends_count': 63,
#    'listed_count': 1,
#    'favourites_count': 434,
#    'statuses_count': 13142,
#    'created_at': 'Fri Dec 09 04:57:13 +0000 2016',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': 'F58EA8',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1018762444116639744/lJNs-G16_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1018762444116639744/lJNs-G16_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807086677315334144/1531531014',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056413987'},
#  {'created_at': 'Fri Jul 20 03:13:34 +0000 2018',
#   'id': 1020144656359862272,
#   'id_str': '1020144656359862272',
#   'text': 'Allllllrighty.......I’m knee deep in  true #summerstyle and this is definitely a version of #whatiworetoday and err… https://t.co/Qs1olpqs1z',
#   'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2718443892,
#    'id_str': '2718443892',
#    'name': 'Top Knot',
#    'screen_name': 'shoptopknotla',
#    'location': 'Los Angeles, CA ',
#    'url': 'http://instagram.com/shoptopknot',
#    'description': 'Affordable rad vintage fashion. Boom. Come and play in my brick and mortar closet and let me fresh dip you like a million bucks!',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 159,
#    'friends_count': 126,
#    'listed_count': 106,
#    'favourites_count': 149,
#    'statuses_count': 6213,
#    'created_at': 'Sat Aug 09 02:51:54 +0000 2014',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/662454603779149824/BnAC6ELk_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/662454603779149824/BnAC6ELk_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2718443892/1446776460',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': {'type': 'Point', 'coordinates': [34.13942581, -118.20074558]},
#   'coordinates': {'type': 'Point',
#    'coordinates': [-118.20074558, 34.13942581]},
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': 'Allllllrighty.......I’m knee deep in  true #summerstyle and this is definitely a version of #whatiworetoday and erryday until the oven turns off! Raisin Hell itty #vintage #tee size… https://t.co/LtUg7g2IG7',
#    'display_text_range': [0, 206],
#    'entities': {'hashtags': [{'text': 'summerstyle', 'indices': [43, 55]},
#      {'text': 'whatiworetoday', 'indices': [92, 107]},
#      {'text': 'vintage', 'indices': [163, 171]},
#      {'text': 'tee', 'indices': [172, 176]}],
#     'urls': [{'url': 'https://t.co/LtUg7g2IG7',
#       'expanded_url': 'https://www.instagram.com/p/BlcB2d0DwXr/?utm_source=ig_twitter_share&igshid=on5q2fg1yk0q',
#       'display_url': 'instagram.com/p/BlcB2d0DwXr/…',
#       'indices': [183, 206]}],
#     'user_mentions': [],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'summerstyle', 'indices': [43, 55]},
#     {'text': 'whatiworetoday', 'indices': [92, 107]}],
#    'urls': [{'url': 'https://t.co/Qs1olpqs1z',
#      'expanded_url': 'https://twitter.com/i/web/status/1020144656359862272',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056414104'},
#  {'created_at': 'Fri Jul 20 03:13:34 +0000 2018',
#   'id': 1020144659895443456,
#   'id_str': '1020144659895443456',
#   'text': '@katzz77 You know it! 😂😂😂🥂',
#   'display_text_range': [9, 26],
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1020144132382224384,
#   'in_reply_to_status_id_str': '1020144132382224384',
#   'in_reply_to_user_id': 4856692203,
#   'in_reply_to_user_id_str': '4856692203',
#   'in_reply_to_screen_name': 'katzz77',
#   'user': {'id': 4870049935,
#    'id_str': '4870049935',
#    'name': 'Helen 🌼🌺',
#    'screen_name': 'HelenMaryMe',
#    'location': 'Los Angeles, CA',
#    'url': 'https://twitter.com/search?f=tweets&vertical=default&q=from%3Ahelenmaryme%20-filter%3Areplies',
#    'description': '❤ Books, Chinese wuxia films, & obscure British comedy. Host of @HashtagGiants & @Monday_Mayhem on @HashtagRoundup.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 17584,
#    'friends_count': 8677,
#    'listed_count': 175,
#    'favourites_count': 122644,
#    'statuses_count': 107390,
#    'created_at': 'Sat Feb 06 19:33:35 +0000 2016',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '009973',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '19CF86',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/971868809052094464/dlsA4Et8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/971868809052094464/dlsA4Et8_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4870049935/1531344297',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'katzz77',
#      'name': 'pK§',
#      'id': 4856692203,
#      'id_str': '4856692203',
#      'indices': [0, 8]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056414947'},
#  {'created_at': 'Fri Jul 20 03:13:35 +0000 2018',
#   'id': 1020144660306571264,
#   'id_str': '1020144660306571264',
#   'text': '@whatwouldroyado He Found a Tinder profile with ya pics and was supposed to meet Rosa lol',
#   'display_text_range': [17, 89],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1020142675784155136,
#   'in_reply_to_status_id_str': '1020142675784155136',
#   'in_reply_to_user_id': 38369075,
#   'in_reply_to_user_id_str': '38369075',
#   'in_reply_to_screen_name': 'whatwouldroyado',
#   'user': {'id': 892877314702180354,
#    'id_str': '892877314702180354',
#    'name': 'Rhys Durrell',
#    'screen_name': 'RhysDurrellW',
#    'location': 'Los Angeles, CA',
#    'url': 'http://thaproducesection.com',
#    'description': 'IG: RhysDurrell | http://ThaProduceSection.com | 717 ➡️ LA',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 316,
#    'friends_count': 289,
#    'listed_count': 2,
#    'favourites_count': 495,
#    'statuses_count': 6850,
#    'created_at': 'Wed Aug 02 22:38:35 +0000 2017',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': 'FAB81E',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1014266180490571777/O_m3aqTT_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1014266180490571777/O_m3aqTT_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/892877314702180354/1501713985',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'whatwouldroyado',
#      'name': 'roboogiewitdahoodie',
#      'id': 38369075,
#      'id_str': '38369075',
#      'indices': [0, 16]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056415045'},
#  {'created_at': 'Fri Jul 20 03:13:35 +0000 2018',
#   'id': 1020144663209000960,
#   'id_str': '1020144663209000960',
#   'text': 'I would do a meet up but I don’t know what to say',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1285286270,
#    'id_str': '1285286270',
#    'name': 'Lauren Tsai ローレンサイ',
#    'screen_name': 'LaLaChuu',
#    'location': 'Honolulu, HI',
#    'url': 'http://Instagram.com/laurentsai',
#    'description': 'twitter',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 76898,
#    'friends_count': 54,
#    'listed_count': 213,
#    'favourites_count': 4675,
#    'statuses_count': 2628,
#    'created_at': 'Thu Mar 21 06:59:15 +0000 2013',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/996421886111186944/4O_7rPU5_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/996421886111186944/4O_7rPU5_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1285286270/1526400368',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056415737'},
#  {'created_at': 'Fri Jul 20 03:13:37 +0000 2018',
#   'id': 1020144670398005248,
#   'id_str': '1020144670398005248',
#   'text': '@yookiemusic Put the tune in the bag https://t.co/NSW0eTK3Sw',
#   'display_text_range': [13, 36],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1020039477732036608,
#   'in_reply_to_status_id_str': '1020039477732036608',
#   'in_reply_to_user_id': 146209833,
#   'in_reply_to_user_id_str': '146209833',
#   'in_reply_to_screen_name': 'yookiemusic',
#   'user': {'id': 290810430,
#    'id_str': '290810430',
#    'name': 'ValleyMerch',
#    'screen_name': 'ValleyMerch',
#    'location': 'Bogotá, Colombia 🇨🇴',
#    'url': 'http://Instagram.com/valleymerch',
#    'description': 'Nursing student🏥. You live, You hurt, You learn, You grow. .👻- Valleymerch',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 1091,
#    'friends_count': 469,
#    'listed_count': 6,
#    'favourites_count': 43231,
#    'statuses_count': 44937,
#    'created_at': 'Sat Apr 30 23:52:32 +0000 2011',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_link_color': 'DD2E44',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1005851102988984326/2Rfo4RaF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1005851102988984326/2Rfo4RaF_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/290810430/1530911946',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'yookiemusic',
#      'name': 'YOOKiE',
#      'id': 146209833,
#      'id_str': '146209833',
#      'indices': [0, 12]}],
#    'symbols': [],
#    'media': [{'id': 1020144665826275329,
#      'id_str': '1020144665826275329',
#      'indices': [37, 60],
#      'media_url': 'http://pbs.twimg.com/media/DihIKyoVsAEH7WB.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DihIKyoVsAEH7WB.jpg',
#      'url': 'https://t.co/NSW0eTK3Sw',
#      'display_url': 'pic.twitter.com/NSW0eTK3Sw',
#      'expanded_url': 'https://twitter.com/ValleyMerch/status/1020144670398005248/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1242, 'h': 836, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 458, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 808, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1020144665826275329,
#      'id_str': '1020144665826275329',
#      'indices': [37, 60],
#      'media_url': 'http://pbs.twimg.com/media/DihIKyoVsAEH7WB.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DihIKyoVsAEH7WB.jpg',
#      'url': 'https://t.co/NSW0eTK3Sw',
#      'display_url': 'pic.twitter.com/NSW0eTK3Sw',
#      'expanded_url': 'https://twitter.com/ValleyMerch/status/1020144670398005248/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1242, 'h': 836, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 458, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 808, 'resize': 'fit'}}}]},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056417451'}]

# %% [markdown]
# Display `tweets` in a DataFrame.

# %%
import pandas as pd
tweets_df=pd.DataFrame(tweets)
tweets_df
# Out:
#   contributors                                        coordinates  \
# 0         None  {'type': 'Point', 'coordinates': [-118.4743643...
# 1         None                                               None
# 2         None                                               None
# 3         None                                               None
# 4         None                                               None
# 5         None  {'type': 'Point', 'coordinates': [-118.2007455...
# 6         None                                               None
# 7         None                                               None
# 8         None                                               None
# 9         None                                               None
#
#                        created_at display_text_range  \
# 0  Fri Jul 20 03:13:27 +0000 2018                NaN
# 1  Fri Jul 20 03:13:30 +0000 2018           [17, 49]
# 2  Fri Jul 20 03:13:32 +0000 2018           [35, 58]
# 3  Fri Jul 20 03:13:33 +0000 2018           [10, 66]
# 4  Fri Jul 20 03:13:33 +0000 2018                NaN
# 5  Fri Jul 20 03:13:34 +0000 2018                NaN
# 6  Fri Jul 20 03:13:34 +0000 2018            [9, 26]
# 7  Fri Jul 20 03:13:35 +0000 2018           [17, 89]
# 8  Fri Jul 20 03:13:35 +0000 2018                NaN
# 9  Fri Jul 20 03:13:37 +0000 2018           [13, 36]
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'statute', 'indices': [...
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 2  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 5  {'hashtags': [{'text': 'summerstyle', 'indices...
# 6  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 7  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 8  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 9  {'hashtags': [], 'urls': [], 'user_mentions': ...
#
#                                    extended_entities  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  {'media': [{'id': 1020144665826275329, 'id_str...
#
#                                       extended_tweet  favorite_count  \
# 0                                                NaN               0
# 1                                                NaN               0
# 2                                                NaN               0
# 3                                                NaN               0
# 4                                                NaN               0
# 5  {'full_text': 'Allllllrighty.......I’m knee de...               0
# 6                                                NaN               0
# 7                                                NaN               0
# 8                                                NaN               0
# 9                                                NaN               0
#
#    favorited filter_level                        ...                          \
# 0      False          low                        ...
# 1      False          low                        ...
# 2      False          low                        ...
# 3      False          low                        ...
# 4      False          low                        ...
# 5      False          low                        ...
# 6      False          low                        ...
# 7      False          low                        ...
# 8      False          low                        ...
# 9      False          low                        ...
#
#   possibly_sensitive  quote_count reply_count retweet_count  retweeted  \
# 0              False            0           0             0      False
# 1                NaN            0           0             0      False
# 2                NaN            0           0             0      False
# 3                NaN            0           0             0      False
# 4                NaN            0           0             0      False
# 5              False            0           0             0      False
# 6                NaN            0           0             0      False
# 7                NaN            0           0             0      False
# 8                NaN            0           0             0      False
# 9              False            0           0             0      False
#
#                                               source  \
# 0  <a href="http://instagram.com" rel="nofollow">...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
# 5  <a href="http://instagram.com" rel="nofollow">...
# 6  <a href="http://twitter.com" rel="nofollow">Tw...
# 7  <a href="http://twitter.com/download/iphone" r...
# 8  <a href="http://twitter.com/download/iphone" r...
# 9  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text   timestamp_ms  \
# 0  #statute @ Venice Boardwalk, CA https://t.co/a...  1532056407818
# 1  @sabbysfirstlove Yess girl recruit new CARPENTERS  1532056410987
# 2  @JKell510 @feedcoop @brittydakitty Ya Bethany ...  1532056412724
# 3  @Lexivnne I recognized that I was wrong and it...  1532056413088
# 4  my truck stay clean from inside , im so OCD wi...  1532056413987
# 5  Allllllrighty.......I’m knee deep in  true #su...  1532056414104
# 6                         @katzz77 You know it! 😂😂😂🥂  1532056414947
# 7  @whatwouldroyado He Found a Tinder profile wit...  1532056415045
# 8  I would do a meet up but I don’t know what to say  1532056415737
# 9  @yookiemusic Put the tune in the bag https://t...  1532056417451
#
#    truncated                                               user
# 0      False  {'id': 30316687, 'id_str': '30316687', 'name':...
# 1      False  {'id': 773726292353187840, 'id_str': '77372629...
# 2      False  {'id': 765683975138357248, 'id_str': '76568397...
# 3      False  {'id': 3279122815, 'id_str': '3279122815', 'na...
# 4      False  {'id': 807086677315334144, 'id_str': '80708667...
# 5       True  {'id': 2718443892, 'id_str': '2718443892', 'na...
# 6      False  {'id': 4870049935, 'id_str': '4870049935', 'na...
# 7      False  {'id': 892877314702180354, 'id_str': '89287731...
# 8      False  {'id': 1285286270, 'id_str': '1285286270', 'na...
# 9      False  {'id': 290810430, 'id_str': '290810430', 'name...
#
# [10 rows x 31 columns]

# %% [markdown]
# Display just the test of the tweets using DataFrame.

# %%
tweets_df.text
# Out:
# 0    #statute @ Venice Boardwalk, CA https://t.co/a...
# 1    @sabbysfirstlove Yess girl recruit new CARPENTERS
# 2    @JKell510 @feedcoop @brittydakitty Ya Bethany ...
# 3    @Lexivnne I recognized that I was wrong and it...
# 4    my truck stay clean from inside , im so OCD wi...
# 5    Allllllrighty.......I’m knee deep in  true #su...
# 6                           @katzz77 You know it! 😂😂😂🥂
# 7    @whatwouldroyado He Found a Tinder profile wit...
# 8    I would do a meet up but I don’t know what to say
# 9    @yookiemusic Put the tune in the bag https://t...
# Name: text, dtype: object

# %% [markdown]
# What is the type of `tweets`?

# %%
type(tweets)
# Out:
# list

# %% [markdown]
# Write a list comprehension to display the type of each of the objects in `tweets`.

# %%
a=[1,'a']
type(a)
for i in range(len(a)):
    print (type(a[i]))
# Out:
# <class 'int'>
# <class 'str'>

# %%
for i in range(length(tweets))

# %% [markdown]
# Import the `json` library.

# %% [markdown]
# Create an object called `tweets_string` using `json.dumps()`.
#
# Display the first 500 characters of this string.

# %% [markdown]
# ## Write Tweets to Disk
#
# Using this pattern
#
#     with open(filename_as_string, 'w') as outfile:
#         json.dump(python_object, outfile)
#
# write `tweets` to disk as json.

# %% [markdown]
# ## Read Tweets from Disk
#
# Using this pattern
#
#     with open(filename_as_string) as infile:
#         json_data=infile.read()
#         python_object_from_disk = json.loads(json_data)
#
# read the tweets from the json. Store them as `tweets_from_disk`.

# %% [markdown]
# Display `tweets_from_disk` as a DataFrame.
